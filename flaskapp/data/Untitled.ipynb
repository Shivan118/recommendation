# %%
import pandas as pd

# %%
jobs = pd.read_csv('jobs.csv')

# %%
jobs.tail()
# Out:
#         Id                Created_date           Due_date  User_id  \
# 2678  2679               Dec 14, 2016        May 01, 2023     2060
# 2679  2680               Nov 21, 2016   December 07, 2020     2061
# 2680  2681               Mar 14, 2016      April 27, 2021     2058
# 2681  2682               Sep 30, 2015   December 31, 2023     2056
# 2682  2683  2021-01-04 10:57:02.130246                NaN     8049
#
#                Payment_type  \
# 2678                 Hourly
# 2679  Fixed Price or Hourly
# 2680                 Hourly
# 2681            Fixed Price
# 2682                    NaN
#
#                                                  Budget  \
# 2678       [' $5 - $10 ', ' 30+ hrs/wk ', ' 6+ months']
# 2679                                                 []
# 2680  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 2681                                      [' $500-$1k']
# 2682                                                NaN
#
# ...

# %%
jobs[jobs['Id']==2683].index[0]
# Out:
# 2682

# %%
print(jobs[jobs['Id'] == 2686]['Skills'].values[0])
# Out:
# ['html', 'css', 'sass', 'javascript', 'reactjs']

# %%
#self.jobs.append({'Id':job.id, 'Created_date':job.date, 'User_id':job.user_id, 'Payment_type':job.payment_type, 'Budget':job.budget, 'Job_title':job.title, 'Category':job.category, 'Subcategory':job.subcategory, 'Job_description':job.description, 'Skills':job.skills, 'Link_of_quoters':job.links_quoters, 'Link_of_invited_freelancers':job.links_invited, 'Link_of_hired_freelancers':job.links_hired, 'Min_budget':job.min_budget, 'Job_cluster_id':job.job_cluster_id}, ignore_index=True)
#self.jobs.to_csv(self.jobs_file)
#self.log_writer.log(self.processLog, 'Failed to read jobs data.')

# %%
row = [2688, ]
row = pd.Series([])

# %%
new_cols = list(jobs.drop(['Unnamed: 0', 'Due_date', 'Name_of_employer', 'Link_of_employer', 'Employer_id', 'No_of_quotes', 'No_of_Premium_quotes', 'Link_of_premium_quoters', 'No_of_inviited', 'No_of_Hired'], axis=1).columns)

# %%
jobs = jobs[new_cols]

# %%
jobs['Min_budget'] = ''

# %%
jobs['Job_cluster_id'] = 0

# %%
jobs = jobs.drop(2681).copy().reset_index(drop=True)

# %%
jobs.tail()
# Out:
#       Unnamed: 0.1    Id                Created_date  User_id  \
# 2677        2677.0  2678               Feb 11, 2017      2058
# 2678        2678.0  2679               Dec 14, 2016      2060
# 2679        2679.0  2680               Nov 21, 2016      2061
# 2680        2680.0  2681               Mar 14, 2016      2058
# 2681           NaN  2683  2021-01-02 14:16:50.719882     8049
#
#                Payment_type  \
# 2677                 Hourly
# 2678                 Hourly
# 2679  Fixed Price or Hourly
# 2680                 Hourly
# 2681                    NaN
#
#                                                  Budget  \
# 2677  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 2678       [' $5 - $10 ', ' 30+ hrs/wk ', ' 6+ months']
# 2679                                                 []
# 2680  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 2681                                                NaN
#
# ...

# %%
jobs['Id'] = (jobs.index.values+1)

# %%
jobs.tail()
# Out:
#       Unnamed: 0.1    Id                Created_date  User_id  \
# 2677        2677.0  2678               Feb 11, 2017      2058
# 2678        2678.0  2679               Dec 14, 2016      2060
# 2679        2679.0  2680               Nov 21, 2016      2061
# 2680        2680.0  2681               Mar 14, 2016      2058
# 2681           NaN  2682  2021-01-02 14:16:50.719882     8049
#
#                Payment_type  \
# 2677                 Hourly
# 2678                 Hourly
# 2679  Fixed Price or Hourly
# 2680                 Hourly
# 2681                    NaN
#
#                                                  Budget  \
# 2677  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 2678       [' $5 - $10 ', ' 30+ hrs/wk ', ' 6+ months']
# 2679                                                 []
# 2680  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 2681                                                NaN
#
# ...

# %%
jobs = jobs.append({'Id':2683, 'Created_date':'January 2, 2021', 'User_id':1111111, 'Payment_type':'', 'Budget':'', 'Job_title':'', 'Category':'', 'Subcategory':'', 'Job_description':'', 'Skills':'', 'Link_of_quoters':'', 'Link_of_invited_freelancers':'', 'Link_of_hired_freelancers':'', 'Min_budget':'', 'Job_cluster_id':'0'}, ignore_index=True)

# %%
jobs
# Out:
#         Id                Created_date           Due_date  User_id  \
# 0        1           December 04, 2020   January 02, 2021        1
# 1        2           December 04, 2020  December 11, 2020        2
# 2        3           December 04, 2020   January 02, 2021        3
# 3        4           December 04, 2020   January 02, 2021        4
# 4        5           December 04, 2020   January 02, 2021        5
# ...    ...                         ...                ...      ...
# 2685  2686  2021-01-02 18:47:04.087347                NaN     8054
# 2686  2687  2021-01-02 18:56:44.154082                NaN     8054
# 2687  2683             January 2, 2021                NaN  1111111
# 2688  2683             January 2, 2021                NaN  1111111
# 2689  2683             January 2, 2021                NaN  1111111
#
#                Payment_type           Budget  \
# 0               Fixed Price    [' $5k-$10k']
# 1               Fixed Price  [' Under $250']
# ...

# %%
import os
os.remove('jobs (copy).csv')

# %%
jobs.to_csv('jobs2.csv', index=False)

# %%
jobs.drop(jobs.columns[jobs.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
jobs
# Out:
#         Id                Created_date           Due_date  User_id  \
# 0        1           December 04, 2020   January 02, 2021        1
# 1        2           December 04, 2020  December 11, 2020        2
# 2        3           December 04, 2020   January 02, 2021        3
# 3        4           December 04, 2020   January 02, 2021        4
# 4        5           December 04, 2020   January 02, 2021        5
# ...    ...                         ...                ...      ...
# 2684  2685  2021-01-02 18:41:21.597227                NaN     8054
# 2685  2686  2021-01-02 18:47:04.087347                NaN     8054
# 2686  2687  2021-01-02 18:56:44.154082                NaN     8054
# 2687  2683             January 2, 2021                NaN  1111111
# 2688  2683             January 2, 2021                NaN  1111111
#
#                Payment_type           Budget  \
# 0               Fixed Price    [' $5k-$10k']
# 1               Fixed Price  [' Under $250']
# ...

# %%
jobs.to_csv('jobs2.csv')

# %%
import string
from stop_words import get_stop_words
stop_words = get_stop_words('english')
def preProcess(skills):
    if isinstance(skills, list):
        s = ' '.join(skills)
    else:
        s = skills
    table = str.maketrans(dict.fromkeys(string.punctuation))
    new_s = s.translate(table)
    new_s = new_s.replace('\n', ' ')
    new_s = new_s.replace('  ', ' ')
    new_s = [x for x in new_s.lower().split() if len(x) > 1 and x not in stop_words]
    return new_s

# %%
preProcess()
# Out:
# ['css']

# %%
df = pd.DataFrame({
        'a': [1, 2, 3],
        'b': [10, 20, 30],
        'c': [100, 200, 300]
    })

# %%
df
# Out:
#    a   b    c
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300

# %%
df.iloc[2]
# Out:
# a      3
# b     30
# c    300
# Name: 2, dtype: int64

# %%
df.loc[3] = {
    'a':4,
    'b':40,
    'c':400
}

# %%
df
# Out:
#    a   b    c
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
